# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# ### Toyota Etios 2014 Dataset (motion)

# %%
df__etios_1=pd.read_csv("Toyota Etios 2014 1.5/live3.csv")

df__etios_1.head()
# Out:
#      ENGINE_RUN_TINE ()  ENGINE_RPM ()  VEHICLE_SPEED ()  THROTTLE ()  \
# 0.0                 0.0            0.0         17.647058          0.0
# 0.0                 0.0            0.0         17.647058          0.0
# 0.0                 0.0            0.0         17.647058          0.0
# 0.0                 0.0            0.0         17.647058          0.0
# 0.0                 0.0            0.0         19.607843          0.0
#
#      ENGINE_LOAD ()  COOLANT_TEMPERATURE ()  LONG_TERM_FUEL_TRIM_BANK_1 ()  \
# 0.0            25.0                 -4.6875                            0.0
# 0.0            25.0                 -4.6875                            0.0
# 0.0            25.0                 -4.6875                            0.0
# 0.0            25.0                 -4.6875                            0.0
# 0.0            25.0                 -4.6875                            0.0
#
#      SHORT_TERM_FUEL_TRIM_BANK_1 ()  INTAKE_MANIFOLD_PRESSURE ()  \
# ...

# %%
df_test= pd.read_csv("exp2_19drivers_1car_1route.csv")
df_test.head()
# Out:
#           TIME      LATITUDE       LONGITUDE  ALTITUDE VEHICLE_ID  \
# 0  1,51336E+12   -58.321.307  -3.520.429.461      46.0        s11
# 1  1,51336E+12   -58.323.103  -3.520.380.397      52.0        s11
# 2  1,51336E+12  -583.251.443  -3.520.323.709      49.0        s11
# 3  1,51336E+12   -58.328.462  -3.520.269.621      45.0        s11
# 4  1,51336E+12  -583.324.508  -3.520.219.432      44.0        s11
#
#   BAROMETRIC_PRESSURE ENGINE_COOLANT_TEMP FUEL_LEVEL ENGINE_LOAD  \
# 0              100kPa                 82C     74,50%      79,20%
# 1              100kPa                 83C     74,10%      78,40%
# 2              100kPa                 83C     73,70%      42,00%
# 3              100kPa                 82C     73,70%      37,30%
# 4              100kPa                 82C     73,30%      76,10%
#
#   AMBIENT_AIR_TEMP  ... FUEL_PRESSURE   SPEED Short Term Fuel Trim Bank 2  \
# 0              28C  ...           NaN  48km/h                         NaN
# ...

# %%
df_test_1= pd.read_csv("exp1_14drivers_14cars_dailyRoutes.csv")
df_test_1.head()
# Out:
# C:\Users\Ahmed Medhat\AppData\Local\Temp\ipykernel_3712\3093985735.py:1: DtypeWarning: Columns (1,2,4,5,6,9,10,14,15,16,20,21,22,23,24,25,26,27) have mixed types. Specify dtype option on import or set low_memory=False.
#   df_test_1= pd.read_csv("exp1_14drivers_14cars_dailyRoutes.csv")
#       TIMESTAMP       MARK  MODEL  CAR_YEAR ENGINE_POWER AUTOMATIC VEHICLE_ID  \
# 0  1.502903e+12  chevrolet  agile    2011.0          1,4         n       car1
# 1  1.502903e+12  chevrolet  agile    2011.0          1,4         n       car1
# 2  1.502903e+12  chevrolet  agile    2011.0          1,4         n       car1
# 3  1.502903e+12  chevrolet  agile    2011.0          1,4         n       car1
# 4  1.502903e+12  chevrolet  agile    2011.0          1,4         n       car1
#
#    BAROMETRIC_PRESSURE(KPA)  ENGINE_COOLANT_TEMP FUEL_LEVEL  ... THROTTLE_POS  \
# 0                     100.0                 80.0     48,60%  ...          25%
# ...

# %%
# df_test_1['MARK']['chevrolet'].unique()
chev_data=df_test_1[df_test_1['MARK'] == 'chevrolet']

# %%
chev_data['CAR_YEAR'].unique()
# Out:
# array([2011.])
