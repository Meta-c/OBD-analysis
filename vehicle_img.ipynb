# %%
import pandas as pd 
import numpy as np 
import matplotlib.pyplot as plt 
import tensorflow as tf

# %%
import cv2

# %%
df = pd.read_csv("Vehicle_images/vehcle_img_data.csv")

df.head()
# Out:
# C:\Users\Ahmed Medhat\AppData\Local\Temp\ipykernel_13192\1858864329.py:1: DtypeWarning: Columns (3) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv("Vehicle_images/vehcle_img_data.csv")
#                                           Image_Path          Brand  \
# 0  vehicle_images/1633889154186_Toyota Hilux 2006...         Toyota
# 1  vehicle_images/1633889154395_Land Rover Freela...     Land Rover
# 2  vehicle_images/1633889154545_Nissan Leaf G Gra...         Nissan
# 3  vehicle_images/1633889154697_Mercedes Benz C20...  Mercedes Benz
# 4  vehicle_images/1633889154870_Toyota Vitz 2018 ...         Toyota
#
#         Model               Edition  Year Condition Transmission         Body  \
# 0       Hilux                 Hilux  2006      Used       Manual    SUV / 4x4
# 1  Freelander                  1999  1999      Used       Manual    SUV / 4x4
# 2        Leaf               G Grade  2014      Used    Automatic    Hatchback
# ...

# %%
import cv2

# Load an image
path = "Vehicle_images/"+df['Image_Path'][3]
print(path)
image = cv2.imread(path)
plt.title(df['Body'][3])
plt.imshow(image)
# # Display the image
# cv2.imshow('Image', image)
# Out:
# Vehicle_images/vehicle_images/1633889154697_Mercedes Benz C200 CCabriolet AMG Line 2016 for sale.jpg
